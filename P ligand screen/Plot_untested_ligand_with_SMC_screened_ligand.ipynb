# %% [markdown]
# # Plot the ligand we want to test vs. screened ligand

# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib widget
# %matplotlib inline

import pandas as pd
from rdkit.Chem import AllChem, MolFromSmiles
from rdkit.Chem.SaltRemover import SaltRemover
from rdkit.Chem import DataStructs
from rdkit import Chem
from rxnfp.tokenization import get_default_tokenizer, SmilesTokenizer
from rdkit.Chem import rdChemReactions

# %%
df = pd.read_excel('P_selected.xlsx', engine = 'openpyxl', sheet_name='Commercials')

# %%
def plot_three_features_with_screened(df_x,i,j,k,df_y):
    fig=plt.figure()
    ax=fig.add_subplot(111,projection='3d')
    n=100
    ax.scatter(df_x[i],df_x[j],df_x[k],c=df_y)
    ax.set_xlabel(i)
    ax.set_ylabel(j)
    ax.set_zlabel(k)
    print("A plot of axis:",i, j, ", and ",k)
    
        
    plt.show()

# %%
plot_three_features_with_screened(df,'x4','x51','x182',df['SMC_dataset'])
# Out:
# A plot of axis: x4 x51 , and  x182

# %%
# Plot a diagram from angle a, b with yields. Remember to use df_origin and df_origin['x198'-'x202'] as input. 
# You can use df_x and df_y, but check and compare the index before use.
def plot_three_features_with_screened_anydir(df_x,i,j,k,df_y,a,b):
    fig=plt.figure()
    ax=fig.add_subplot(111,projection='3d')
    n=100
    ax.scatter(df_x[i],df_x[j],df_x[k],c=df_y)
    ax.set_xlabel(i)
    ax.set_ylabel(j)
    ax.set_zlabel(k)
    print("A plot of axis:",i, j, ", and ",k)
    # rotate the axes by angles you want
    ax.view_init(a,b)
        
    plt.show()

# %%
# Plot 'fraction=12' number of diagrams from different angles, rotating 360/fraction degrees at a time.
blist=[]
a=0
fraction = 12
for i in range(0,fraction):
    blist.append(i*(360/fraction))
for i in blist:
    plot_three_features_with_screened_anydir(df,'x4','x51','x182',df['SMC_dataset'],a,i)
# Out:
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
# A plot of axis: x4 x51 , and  x182
